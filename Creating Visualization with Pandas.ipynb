# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\ALP_TUF\Desktop\DATA_ANALYST_TUTORIAL\Pandas\Ice Cream Ratings.csv")

# %%
df
# Out:
#        Date  Flavor Rating  Texture Rating  Overall Rating
# 0  1/1/2022       0.223090        0.040220        0.600129
# 1  1/2/2022       0.635886        0.938476        0.106264
# 2  1/3/2022       0.442323        0.044154        0.598112
# 3  1/4/2022       0.389128        0.549676        0.489353
# 4  1/5/2022       0.386887        0.519439        0.988280
# 5  1/6/2022       0.877984        0.193588        0.832827
# 6  1/7/2022       0.140995        0.325110        0.105147

# %%
df = df.set_index('Date')

# %%
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
# check plot style theme

print(plt.style.available)
plt.style.use('fivethirtyeight')
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4416/280740424.py in <module>
#       1 # check plot style theme
#       2
# ----> 3 print(plt.style.avalable)
#
# AttributeError: module 'matplotlib.style' has no attribute 'avalable'

# %%
df.plot(kind = 'line')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Breaking by column
df.plot(kind = 'line', subplots = True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>], dtype=object)

# %%
df.plot(kind = 'line', title =  "ICE CREAM RATINGS")
# Out:
# <AxesSubplot:title={'center':'ICE CREAM RATINGS'}, xlabel='Date'>

# %%
df.plot(kind = 'line', title =  'ICE CREAM RATINGS', xlabel = 'Daily Ratings', ylabel = 'Scores')
# Out:
# <AxesSubplot:title={'center':'ICE CREAM RATINGS'}, xlabel='Daily Ratings', ylabel='Scores'>

# %%
# BAR PLOT

df.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Stacked BAR PLOT

df.plot(kind = 'bar', stacked = True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Specify which ones to plot

df['Flavor Rating'].plot(kind = 'bar', stacked = True, title = " Flavor Rating ")
# Out:
# <AxesSubplot:title={'center':' Flavor Rating '}, xlabel='Date'>

# %%
# Horizontal bar

df.plot.barh(stacked = True, title = " Flavor Rating ")
# Out:
# <AxesSubplot:title={'center':' Flavor Rating '}, ylabel='Date'>

# %%
# scatter plot

df.plot.scatter(x = 'Texture Rating', y = 'Overall Rating')
# Out:
# <AxesSubplot:xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
# Change size, & color
df.plot.scatter(x = 'Texture Rating', y = 'Overall Rating', s = 500, color = 'red')
# Out:
# <AxesSubplot:xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
# histogram 

df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#= specify bins
df.plot.hist(bins = 6)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# BOX PLOT

df.boxplot()
# Out:
# <AxesSubplot:>

# %%
# Area plot

df.plot.area()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# CHANGE SIZE

df.plot.area(figsize = (10, 5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# PIE CHART

df.plot.pie(y = 'Flavor Rating')
# Out:
# <AxesSubplot:ylabel='Flavor Rating'>

# %%
df.plot.pie(y = 'Flavor Rating', figsize = (10, 6))
# Out:
# <AxesSubplot:ylabel='Flavor Rating'>
